# %%
import pandas as pd

# %%
character_data = pd.read_csv("over_one_mil_chars.csv")

# %%
character_data.head()
# Out:
#    Unnamed: 0  char_id                name  base_hp  stats_1  stats_2  \
# 0           0        1             Molster        8       11       22
# 1           1        3             Prailak      103       12       17
# 2           2        8           Aurilanax       76       18       10
# 3           3       10  Gamndell Banglebon      127       10       14
# 4           4       19      Bellek Bouncer       52       10       10
#
#    stats_3  stats_4  stats_5  stats_6  ... class_starting_level  \
# 0       11       17       20       12  ...                    4
# 1       18       14       16       16  ...                   20
# 2       16       13       13       16  ...                    7
# 3       16       16       15       18  ...                    2
# 4       15       12       14       10  ...                    6
#
#    subclass_starting         class_other      subclass_other total_level  \
# 0                NaN                 NaN                 NaN           4
# ...

# %%
character_data.drop(columns="Unnamed: 0", inplace=True)

# %%
character_data[character_data.duplicated()].head()
# Out:
#         char_id                 name  base_hp  stats_1  stats_2  stats_3  \
# 293785   293809  Laetorius Perennius       10       12       15       11
# 293786   293817                Zecil       10        0        0        0
# 293787   293820                 Tjdj        8       12       15       13
# 293788   293821       Lexos Diharis        69       12       12       15
# 293789   293822             Syllamir        8       11       17       11
#
#         stats_4  stats_5  stats_6           background  ...  \
# 293785        9        9       15              Soldier  ...
# 293786        0        0        0                  NaN  ...
# 293787        8       14       10              Soldier  ...
# 293788       13       17       12              Acolyte  ...
# 293789       11       12       16  Urban Bounty Hunter  ...
#
#        class_starting_level subclass_starting  class_other subclass_other  \
# 293785                    1               NaN          NaN            NaN
# ...

# %%
character_data.drop_duplicates(inplace=True)

# %%
character_data.count()
# Out:
# char_id                 511318
# name                    509454
# base_hp                 511318
# stats_1                 511318
# stats_2                 511318
# stats_3                 511318
# stats_4                 511318
# stats_5                 511318
# stats_6                 511318
# background              378601
# race                    511318
# class_starting          511318
# class_starting_level    511318
# subclass_starting       254814
# class_other              33247
# subclass_other           20607
# total_level             511318
# feats                    90761
# inventory               345026
# date_modified           511318
# notes_len               511318
# gold                    511318
# dtype: int64

# %%
character_data.to_csv("over_one_mil_chars_shrunk.csv")

# %%
character_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 511318 entries, 0 to 1185824
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   char_id               511318 non-null  int64
#  1   name                  509454 non-null  object
#  2   base_hp               511318 non-null  int64
#  3   stats_1               511318 non-null  int64
#  4   stats_2               511318 non-null  int64
#  5   stats_3               511318 non-null  int64
#  6   stats_4               511318 non-null  int64
#  7   stats_5               511318 non-null  int64
#  8   stats_6               511318 non-null  int64
#  9   background            378601 non-null  object
#  10  race                  511318 non-null  object
#  11  class_starting        511318 non-null  object
#  12  class_starting_level  511318 non-null  int64
#  13  subclass_starting     254814 non-null  object
# ...
